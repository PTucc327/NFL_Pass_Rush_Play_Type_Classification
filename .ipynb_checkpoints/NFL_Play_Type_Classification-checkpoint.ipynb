# %% [markdown]
# # NFL Play Type Classificaiton
# By: Paul Tuccinardi

# %% [markdown]
# ## Introduction

# %% [markdown]
# In the NFL, there are 32 teams each choosing plays of the same type(pass,run). During the 2024 season passing plays were 58%, and running plays were 42%. While this is just the average of the league as a whole, each team has a slightly different percentage of pass and run plays. The plays teams choose to run varies based on game situations(ex. 3rd and 1 vs 3rd and 10). Understanding these choices is important in uncovering team strategies, and their decision making process.

# %% [markdown]
# ## Goal

# %% [markdown]
# To create a Machine Learning model that can predict what type of play will occur based on game situation.

# %% [markdown]
# ## Pulling Data

# %%
import nfl_data_py as nfl
import pandas as pd

# %%
years = [2023,2024]
data = nfl.import_pbp_data(years, downcast=True, cache=False, alt_path=None)
df = pd.DataFrame(data)
print(df)
# Out:
# 2023 done.
# 2024 done.
# Downcasting floats.
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 0          1.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 1         39.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 2         55.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 3         77.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 4        102.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# ...        ...              ...           ...       ...       ...         ...
# 99152   4158.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99153   4181.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99154   4203.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99155   4225.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Selecting pre play features and target feature

# %%
#These are features that provide insights prior to the play happening and run information, play_type will be the target feature for this project
features = [
    'down', 'ydstogo', 'yardline_100', 'qtr', 'drive',
    'half_seconds_remaining', 'score_differential',
    'posteam', 'defteam', 'play_type_nfl', 'home_team','away_team', 
    'shotgun', 'away_wp','home_wp', 'no_huddle', 
    'total_home_rush_epa', 'total_away_rush_epa', 'total_home_pass_epa','total_away_pass_epa',
    'home_timeouts_remaining','away_timeouts_remaining', 'defense_coverage_type', 'offense_formation', 'yards_gained'
]

df = df[features]

# %%
print(df.head())
# Out:
#    down  ydstogo  yardline_100  qtr  drive  half_seconds_remaining  \
# 0   NaN      0.0           NaN  1.0    NaN                  1800.0
# 1   NaN      0.0          35.0  1.0    1.0                  1800.0
# 2   1.0     10.0          75.0  1.0    1.0                  1800.0
# 3   2.0      7.0          72.0  1.0    1.0                  1770.0
# 4   3.0      1.0          66.0  1.0    1.0                  1735.0
#
#    score_differential posteam defteam play_type_nfl  ... no_huddle  \
# 0                 NaN    None    None    GAME_START  ...       0.0
# 1                 0.0     WAS     ARI      KICK_OFF  ...       0.0
# 2                 0.0     WAS     ARI          RUSH  ...       0.0
# 3                 0.0     WAS     ARI          PASS  ...       0.0
# 4                 0.0     WAS     ARI          RUSH  ...       0.0
#
#   total_home_rush_epa  total_away_rush_epa  total_home_pass_epa  \
# 0            0.000000             0.000000             0.000000
# ...

# %%
#get an idea of how the data is spread out
print(df.describe())
# Out:
#                down       ydstogo  yardline_100           qtr         drive  \
# count  83408.000000  99157.000000  92155.000000  99157.000000  98027.000000
# mean       2.005071      7.149148     48.097511      2.564539     11.438553
# std        1.006795      4.911860     24.009861      1.127472      6.664973
# min        1.000000      0.000000      1.000000      1.000000      1.000000
# 25%        1.000000      3.000000     31.000000      2.000000      6.000000
# 50%        2.000000      9.000000     50.000000      2.000000     11.000000
# 75%        3.000000     10.000000     69.000000      4.000000     17.000000
# max        4.000000     40.000000     99.000000      5.000000     34.000000
#
#        half_seconds_remaining  score_differential       shotgun       away_wp  \
# count            99147.000000        93806.000000  99157.000000  99157.000000
# mean               804.577942           -1.267584      0.544994      0.444217
# ...

# %%
#check data types
print(df.dtypes)
# Out:
# down                       float32
# ydstogo                    float32
# yardline_100               float32
# qtr                        float32
# drive                      float32
# half_seconds_remaining     float32
# score_differential         float32
# posteam                     object
# defteam                     object
# play_type_nfl               object
# home_team                   object
# away_team                   object
# shotgun                    float32
# away_wp                    float32
# home_wp                    float32
# no_huddle                  float32
# total_home_rush_epa        float32
# total_away_rush_epa        float32
# total_home_pass_epa        float32
# total_away_pass_epa        float32
# home_timeouts_remaining    float32
# away_timeouts_remaining    float32
# defense_coverage_type       object
# offense_formation           object
# yards_gained               float32
# dtype: object

# %%
#Check for missing values in features and sort them so most missing is at the top
print((df.isna().sum().sort_values(ascending=False)))
# Out:
# defense_coverage_type      53833
# offense_formation          25516
# down                       15749
# yardline_100                7002
# posteam                     5351
# defteam                     5351
# score_differential          5351
# yards_gained                3005
# drive                       1130
# half_seconds_remaining        10
# total_away_rush_epa            0
# qtr                            0
# away_timeouts_remaining        0
# home_timeouts_remaining        0
# total_away_pass_epa            0
# total_home_pass_epa            0
# total_home_rush_epa            0
# play_type_nfl                  0
# no_huddle                      0
# home_wp                        0
# away_wp                        0
# ydstogo                        0
# away_team                      0
# home_team                      0
# shotgun                        0
# dtype: int64

# %%
#dropping na rows in the following features
drop_features = ['down', 'yardline_100', 'posteam', 'defteam','half_seconds_remaining']
df = df.dropna(subset=drop_features)

# %%
df['drive'] = df['drive'].fillna(0)

# %%
#fill features with text with unknown as it is not clear what type of formation they had
fill_unknown_features = ['defense_coverage_type', 'offense_formation']
df[fill_unknown_features] = df[fill_unknown_features].fillna('UNKOWN')

# %%
#Check how much of the data is unkown to see if the field will still provide valuable insights
print(df['offense_formation'].value_counts().head(10))
print(df['defense_coverage_type'].value_counts().head(10))
# Out:
# SHOTGUN         48088
# UNDER CENTER    20423
# UNKOWN          10056
# PISTOL           4841
# Name: offense_formation, dtype: int64
# UNKOWN     38298
# COVER_1    15769
# COVER_2     8030
# COVER_3     7947
# COVER_4     4109
# 2_MAN       3092
# COVER_6     1934
# COVER_0     1709
# COMBO       1657
# COVER_9      790
# Name: defense_coverage_type, dtype: int64

# %%
#check to make sure all na values are dealt with
print((df.isna().sum().sort_values(ascending=False)))
# Out:
# yards_gained               110
# away_wp                      0
# offense_formation            0
# defense_coverage_type        0
# away_timeouts_remaining      0
# home_timeouts_remaining      0
# total_away_pass_epa          0
# total_home_pass_epa          0
# total_away_rush_epa          0
# total_home_rush_epa          0
# no_huddle                    0
# home_wp                      0
# down                         0
# ydstogo                      0
# away_team                    0
# home_team                    0
# play_type_nfl                0
# defteam                      0
# posteam                      0
# score_differential           0
# half_seconds_remaining       0
# drive                        0
# qtr                          0
# yardline_100                 0
# shotgun                      0
# dtype: int64

# %%
#get the final size of the dataset being used
df.size
# Out:
# 2085200

# %%
#get the number of rows in the dataset
len(df)
# Out:
# 83408

# %% [markdown]
# ### Visualizations - Play types

# %%
#check overall the different plays made
df['play_type_nfl'].value_counts().plot(kind='bar')
plt.title('Distribution of plays in NFL')
plt.xlabel('Type of play')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()

# %%
#Looking at the NY giants play distributions
giants = df[df['posteam']=='NYG']
giants['play_type_nfl'].value_counts().plot(kind='bar', color='blue')
plt.title('Distribution of plays made by NY Giants')
plt.xlabel('Type of play')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()

# %%
##Looking at the PHI Eagles play distributions
eagles = df[df['posteam']=='PHI']
eagles['play_type_nfl'].value_counts().plot(kind='bar', color='green')
plt.title('Distribution of plays made by Eagles')
plt.xlabel('Type of play')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()

# %%
#Looking at the KC Chiefs play distributions
chiefs = df[df['posteam']=='KC']
chiefs['play_type_nfl'].value_counts().plot(kind='bar', color='red')
plt.title('Distribution of plays made by Chiefs')
plt.xlabel('Type of play')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Looking at the distributions of plays made in the NFL for the 2023 and 2024 seasons, Most plays made were passing above 35,000 and rushing plays made up about 30,000. Looking at the NY Giants they had a closer rushing and passing play ratio, however they did more punt plays than have penalty plays. With the PHI Eagles, they have an even closer passing rushing ratio. With the KC Chiefs, had a larger ratio of passing plays to rushing plays. With this knowledge it is clear that each team has a different strategy in games, some teams like the KC Chiefs rely more on passing plays, where as teams like NY Giants and PHI Eagles have a more even distribution of passing plays and rushing plays.

# %% [markdown]
# ### Visualization - Downs

# %%
#get an idea of how many downs were made
df['down'].value_counts().plot(kind='bar')
plt.title('# of Downs')
plt.xlabel('Downs')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Visualization - Offensive and Defensive formations

# %%
#visualize the distribution of offensive formations
df['offense_formation'].value_counts().plot(kind='bar')
plt.title('# of each offensive formations')
plt.xlabel('Offense Formation')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#visualize the defensive coverage types
df['defense_coverage_type'].value_counts().plot(kind='bar')
plt.title('# of each Defensive coverage type')
plt.xlabel('Defensive Coverage')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# With offensive formations, shotgun seems to be the most widely used with under center kind of used, and pistol formation rarely used. When it comes to the defensive coverage types, almost half of the data is unknown, however it can still be noticed that cover_1, cover_2, and cover_3 are the most chosen defensive coverage types from the data above. Options like Combo or cover_9 might be calls in specific situations, like punting the ball, or for field goal attempts.

# %% [markdown]
# ### Correlation of features

# %%
#Get the correlation between features
correlation  = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\Paul Tuccinardi\AppData\Local\Temp\ipykernel_5928\1710212501.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation  = df.corr()

# %% [markdown]
# When looking at the correlations between features, it can be noticed that drive and quarter are highly correlated. Quarter, drive, and half seconds remaining are correlated with the remaining timeouts teams have. From my experience watching Football games, most teams save timeouts for crucial moments which typically happen towards the end of the half. The win percentages for each team is correlated with the home rush and pass epa as well as away rush and pass epa. It can also be noticed, that there are some smaller correlations between score_differential, shotgun, and no_huddle. This helps show some relation to what is happening on the field during the game. When teams don't go in for a huddle there are most likely running one of a few plays, and not providing the defense time to substitute players and make adjustments.

# %% [markdown]
# ### Rush vs Pass

# %%
# Ensure only relevant plays are included (should already be true in your filtered data)
df_viz = df[df['play_type_nfl'].isin(['PASS', 'RUSH'])]

# Compute the average yards gained for each play type
avg_yards = df_viz.groupby('play_type_nfl')['yards_gained'].mean().reset_index()

# Sort play types to keep consistent order
avg_yards = avg_yards.sort_values(by='yards_gained', ascending=False)

# Plot
plt.figure(figsize=(8,6))
sns.barplot(data=avg_yards, x='play_type_nfl', y='yards_gained')

# Add value labels on bars
for index, row in avg_yards.iterrows():
    plt.text(index, row['yards_gained'] + 0.1, f"{row['yards_gained']:.2f}", ha='center', fontsize=10)

plt.title('Average Yards Gained by Play Type', fontsize=14, weight='bold')
plt.xlabel('Play Type')
plt.ylabel('Average Yards Gained')
plt.tight_layout()
plt.show()

# %%
# Ensure only relevant plays are included (should already be true in your filtered data)

chiefs_viz = chiefs[chiefs['play_type_nfl'].isin(['PASS', 'RUSH'])]

# Compute the average yards gained for each play type
avg_yards = chiefs_viz.groupby('play_type_nfl')['yards_gained'].mean().reset_index()

# Sort play types to keep consistent order
avg_yards = avg_yards.sort_values(by='yards_gained', ascending=False)

# Plot
plt.figure(figsize=(8,6))
sns.barplot(data=avg_yards, x='play_type_nfl', y='yards_gained', color='red')

# Add value labels on bars
for index, row in avg_yards.iterrows():
    plt.text(index, row['yards_gained'] + 0.1, f"{row['yards_gained']:.2f}", ha='center', fontsize=10)

plt.title('Average Yards Gained by Chiefs', fontsize=14, weight='bold')
plt.xlabel('Play Type')
plt.ylabel('Average Yards Gained')
plt.tight_layout()
plt.show()

# %%
# Ensure only relevant plays are included (should already be true in your filtered data)
giants_viz = giants[giants['play_type_nfl'].isin(['PASS', 'RUSH'])]

# Compute the average yards gained for each play type
avg_yards = giants_viz.groupby('play_type_nfl')['yards_gained'].mean().reset_index()

# Sort play types to keep consistent order
avg_yards = avg_yards.sort_values(by='yards_gained', ascending=False)

# Plot
plt.figure(figsize=(8,6))
sns.barplot(data=avg_yards, x='play_type_nfl', y='yards_gained', color='blue')

# Add value labels on bars
for index, row in avg_yards.iterrows():
    plt.text(index, row['yards_gained'] + 0.1, f"{row['yards_gained']:.2f}", ha='center', fontsize=10)

plt.title('Average Yards Gained by Giants', fontsize=14, weight='bold')
plt.xlabel('Play Type')
plt.ylabel('Average Yards Gained')
plt.tight_layout()
plt.show()

# %%
# Ensure only relevant plays are included (should already be true in your filtered data)
eagles_viz = eagles[eagles['play_type_nfl'].isin(['PASS', 'RUSH'])]

# Compute the average yards gained for each play type
avg_yards = eagles_viz.groupby('play_type_nfl')['yards_gained'].mean().reset_index()

# Sort play types to keep consistent order
avg_yards = avg_yards.sort_values(by='yards_gained', ascending=False)

# Plot
plt.figure(figsize=(8,6))
sns.barplot(data=avg_yards, x='play_type_nfl', y='yards_gained', color= 'green')

# Add value labels on bars
for index, row in avg_yards.iterrows():
    plt.text(index, row['yards_gained'] + 0.1, f"{row['yards_gained']:.2f}", ha='center', fontsize=10)

plt.title('Average Yards Gained by Eagles', fontsize=14, weight='bold')
plt.xlabel('Play Type')
plt.ylabel('Average Yards Gained')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df= df.drop('yards_gained', axis=1)
df_copy = df[df['play_type_nfl'].isin(['PASS', 'RUSH'])].copy()
df_copy['play_type_nfl'] = df['play_type_nfl'].map({'PASS': 1, 'RUSH': 0})

# %%
features = [
    'down', 'ydstogo', 'yardline_100', 'qtr', 'drive',
    'half_seconds_remaining', 'score_differential',
    'posteam', 'defteam', 'home_team','away_team', 
    'shotgun', 'away_wp','home_wp', 'no_huddle', 
    'total_home_rush_epa', 'total_away_rush_epa', 'total_home_pass_epa','total_away_pass_epa',
    'home_timeouts_remaining','away_timeouts_remaining', 
    'defense_coverage_type', 'offense_formation'
]

# %%
categorical_features=['home_team','away_team','posteam','defteam', 'shotgun', 'no_huddle','defense_coverage_type', 'offense_formation']
numeric_features = [ 'down', 'ydstogo', 'yardline_100', 'qtr', 'drive',
    'half_seconds_remaining', 'score_differential','away_wp','home_wp','total_home_rush_epa', 'total_away_rush_epa', 'total_home_pass_epa','total_away_pass_epa',
    'home_timeouts_remaining','away_timeouts_remaining']

# %%
from sklearn.model_selection import train_test_split
X= df_copy.drop('play_type_nfl', axis=1).copy()
y= df_copy['play_type_nfl']

# %%
from sklearn.preprocessing import LabelEncoder

# Encode y once
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_encoded, test_size = 0.2, random_state= 42, stratify= y)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Imports

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
import xgboost as xgb

# %% [markdown]
# ### Logistic Regression

# %%
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
scaler = StandardScaler()

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', ohe, categorical_features),
        ('num', scaler, numeric_features)
    ]
)

# Pipeline
log_reg_model = Pipeline(steps=[
    ("prep", preprocessor),
    ("model", LogisticRegression(max_iter=500))
])

# Fit the FULL pipeline (this also fits the preprocessor!)
log_reg_model.fit(X_train, y_train)

# Evaluate
y_pred = log_reg_model.predict(X_test)

# %%
log_reg_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['home_team', 'away_team',
#                                                    'posteam', 'defteam',
#                                                    'shotgun', 'no_huddle',
#                                                    'defense_coverage_type',
#                                                    'offense_formation']),
#                                                  ('num', StandardScaler(),
#                                                   ['down', 'ydstogo',
#                                                    'yardline_100', 'qtr',
#                                                    'drive',
# ...

# %%
y_pred_lr = log_reg_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
print(f'Accuracy of the model is:  {accuracy}')
print(f'Classification Report of the model is: \n {report}')
# Out:
# Accuracy of the model is:  0.9645022925602722
# Classification Report of the model is:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      6139
#            1       0.94      0.99      0.97      7383
#
#     accuracy                           0.96     13522
#    macro avg       0.97      0.96      0.96     13522
# weighted avg       0.97      0.96      0.96     13522

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=log_reg_model.classes_)
cm_display.plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### RandomForest Classifier

# %%
from sklearn.pipeline import Pipeline
rf = Pipeline([
    ('prep', preprocessor),
    ('model', RandomForestClassifier())
])

# %%
rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['home_team', 'away_team',
#                                                    'posteam', 'defteam',
#                                                    'shotgun', 'no_huddle',
#                                                    'defense_coverage_type',
#                                                    'offense_formation']),
#                                                  ('num', StandardScaler(),
#                                                   ['down', 'ydstogo',
#                                                    'yardline_100', 'qtr',
#                                                    'drive',
# ...

# %%
y_pred_rf = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_rf)
report = classification_report(y_test, y_pred_rf)

# %%
print(f'Accuracy of the model is:  {accuracy}')
print(f'Classification Report of the model is: \n {report}')
# Out:
# Accuracy of the model is:  0.9662771779322585
# Classification Report of the model is:
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96      6139
#            1       0.94      1.00      0.97      7383
#
#     accuracy                           0.97     13522
#    macro avg       0.97      0.96      0.97     13522
# weighted avg       0.97      0.97      0.97     13522

# %%
cm = confusion_matrix(y_test, y_pred_rf)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)
cm_display.plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier


xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='logloss'
)

pipeline_xgb = Pipeline(steps=[
    ("prep", preprocessor),   # SAME preprocessor you use for every model
    ("model", xgb_model)
])

# %%
pipeline_xgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['home_team', 'away_team',
#                                                    'posteam', 'defteam',
#                                                    'shotgun', 'no_huddle',
#                                                    'defense_coverage_type',
#                                                    'offense_formation']),
#                                                  ('num', StandardScaler(),
#                                                   ['down', 'ydstogo',
#                                                    'yardline_100', 'qtr',
#                                                    'drive',
# ...

# %%
y_pred_xgb = pipeline_xgb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_xgb)
report = classification_report(y_test, y_pred_xgb)

# %%
print(f'Accuracy of the model is:  {accuracy}')
print(f'Classification Report of the model is: \n {report}')
# Out:
# Accuracy of the model is:  0.9666469457180891
# Classification Report of the model is:
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96      6139
#            1       0.94      1.00      0.97      7383
#
#     accuracy                           0.97     13522
#    macro avg       0.97      0.96      0.97     13522
# weighted avg       0.97      0.97      0.97     13522

# %%
cm = confusion_matrix(y_test, y_pred_xgb)

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline_xgb.classes_)
cm_display.plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Results

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_recall_fscore_support

results = []
results.append({"model":"LogReg", "accuracy": accuracy_score(y_test, y_pred), "macro_f1": f1_score(y_test, y_pred, average="macro")})
results.append({"model":"RandomForest", "accuracy": accuracy_score(y_test, y_pred_rf), "macro_f1": f1_score(y_test, y_pred_rf, average="macro")})
results.append({"model":"XGBoost", "accuracy": accuracy_score(y_test, y_pred_xgb), "macro_f1": f1_score(y_test, y_pred_xgb, average="macro")})
# results.append({"model": "XGBoost2", "accuracy": accuracy_score(y_test,y_pred_xgb_2), "macro_f1": f1_score(y_test,y_pred_xgb_2, average="macro")})

results_df = pd.DataFrame(results).sort_values(by="macro_f1", ascending=False)
results_df
# Out:
#           model  accuracy  macro_f1
# 2       XGBoost  0.966647  0.966138
# 1  RandomForest  0.966277  0.965764
# 0        LogReg  0.964502  0.963978

# %%
#save the xgboost model since it performed the best
import joblib
joblib.dump(preprocessor, "preprocessor.joblib")
joblib.dump(pipeline_xgb, "xgb_model.joblib")
joblib.dump(label_encoder, "label_encoder.joblib")
print("Saved: preprocessor.joblib, xgb_model.joblib, label_encoder.joblib")
# Out:
# Saved: preprocessor.joblib, xgb_model.joblib, label_encoder.joblib

# %% [markdown]
# ## Evaluating Model performance

# %%
def predict_play_type(model,
                      down=None,
                      ydstogo=None,
                      yardline_100=None,
                      qtr=None,
                      drive=None,
                      half_seconds_remaining=None,
                      score_differential=None,
                      posteam=None,
                      defteam=None,
                      home_team=None,
                      away_team=None,
                      shotgun=None,
                      away_wp=None,
                      home_wp=None,
                      no_huddle=None,
                      total_home_rush_epa=None,
                      total_away_rush_epa=None,
                      total_home_pass_epa=None,
                      total_away_pass_epa=None,
                      home_timeouts_remaining=None,
                      away_timeouts_remaining=None,
                      defense_coverage_type=None,
                      offense_formation=None):

    # Raw 1-row dataframe
    sample = {
        'down': down,
        'ydstogo': ydstogo,
        'yardline_100': yardline_100,
        'qtr': qtr,
        'drive': drive,
        'half_seconds_remaining': half_seconds_remaining,
        'score_differential': score_differential,
        'posteam': posteam,
        'defteam': defteam,
        'home_team': home_team,
        'away_team': away_team,
        'shotgun': shotgun,
        'away_wp': away_wp,
        'home_wp': home_wp,
        'no_huddle': no_huddle,
        'total_home_rush_epa': total_home_rush_epa,
        'total_away_rush_epa': total_away_rush_epa,
        'total_home_pass_epa': total_home_pass_epa,
        'total_away_pass_epa': total_away_pass_epa,
        'home_timeouts_remaining': home_timeouts_remaining,
        'away_timeouts_remaining': away_timeouts_remaining,
        'defense_coverage_type': defense_coverage_type,
        'offense_formation': offense_formation
    }

    X_sample = pd.DataFrame([sample])

    # Send raw sample directly into the pipeline
    pred = model.predict(X_sample)[0]

    return "PASS" if pred == 1 else "RUN"

# %%
predict_play_type(
    pipeline_xgb,
    down=3,
    ydstogo=8,
    yardline_100=50,
    qtr=4,
    drive=12,
    half_seconds_remaining=180,   # 3 minutes left
    score_differential=-7,        # losing by 7
    posteam="KC",
    defteam="BUF",
    home_team="KC",
    away_team="BUF",
    shotgun=1,
    away_wp=0.65,
    home_wp=0.35,
    no_huddle=0,
    total_home_rush_epa=12.3,
    total_away_rush_epa=8.4,
    total_home_pass_epa=25.1,
    total_away_pass_epa=18.7,
    home_timeouts_remaining=2,
    away_timeouts_remaining=3,
    defense_coverage_type="COVER_2",
    offense_formation="SHOTGUN"
)
# Out:
# 'PASS'

# %% [markdown]
# ### Testing with 2025 data

# %%
years = [2025]
data = nfl.import_pbp_data(years, downcast=True, cache=False, alt_path=None)
df_2025 = pd.DataFrame(data)
print(df_2025)
# Out:
# 2025 done.
# Downcasting floats.
#        play_id          game_id old_game_id home_team away_team season_type  \
# 0          1.0   2025_01_ARI_NO  2025090705        NO       ARI         REG
# 1         40.0   2025_01_ARI_NO  2025090705        NO       ARI         REG
# 2         63.0   2025_01_ARI_NO  2025090705        NO       ARI         REG
# 3         85.0   2025_01_ARI_NO  2025090705        NO       ARI         REG
# 4        115.0   2025_01_ARI_NO  2025090705        NO       ARI         REG
# ...        ...              ...         ...       ...       ...         ...
# 35513   3378.0  2025_14_WAS_MIN  2025120705       MIN       WAS         REG
# 35514   3404.0  2025_14_WAS_MIN  2025120705       MIN       WAS         REG
# 35515   3433.0  2025_14_WAS_MIN  2025120705       MIN       WAS         REG
# 35516   3455.0  2025_14_WAS_MIN  2025120705       MIN       WAS         REG
# 35517   3477.0  2025_14_WAS_MIN  2025120705       MIN       WAS         REG
#
# ...

# %%
#These are features that provide insights prior to the play happening and run information, play_type will be the target feature for this project
features = [
    'down', 'ydstogo', 'yardline_100', 'qtr', 'drive',
    'half_seconds_remaining', 'score_differential',
    'posteam', 'defteam', 'home_team','away_team', 
    'shotgun', 'away_wp','home_wp', 'no_huddle', 'play_type_nfl',
    'total_home_rush_epa', 'total_away_rush_epa', 'total_home_pass_epa','total_away_pass_epa',
    'home_timeouts_remaining','away_timeouts_remaining'
]

df_2025 = df_2025[features]

# %%
df_2025['defense_coverage_type'] = 'UNKNOWN'
df_2025['offense_formation'] = 'UNKNOWN'

# %%
drop_features = ['down', 'yardline_100', 'posteam', 'defteam','half_seconds_remaining']
df_2025 = df_2025.dropna(subset=drop_features)

# %%
df_2025['drive'] = df_2025['drive'].fillna(0)

# %%
df_2025["play_type_nfl"] = df_2025["play_type_nfl"].map({"pass": 1, "run": 0})

# %%
X_2025= df_copy.drop('play_type_nfl', axis=1).copy()
y_2025= df_copy['play_type_nfl']

# %%
y_pred_2025 = pipeline_xgb.predict(X_2025)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

print("Accuracy:", accuracy_score(y_2025, y_pred_2025))
print("Precision:", precision_score(y_2025, y_pred_2025))
print("Recall:", recall_score(y_2025, y_pred_2025))
print("F1 Score:", f1_score(y_2025, y_pred_2025))
# Out:
# Accuracy: 0.9675921132427115
# Precision: 0.9453822473063109
# Recall: 0.9983203749356595
# F1 Score: 0.9711304072839392

# %%
cm = confusion_matrix(y_2025, y_pred_2025)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline_xgb.classes_)
cm_display.plot()
plt.title("Confusion Matrix")
plt.show()

# %%
# NOTE: This code assumes you have successfully loaded the 'pipeline_xgb' and 'preprocessor'
# objects after training, as described in your notebook.

# 1. Get the names of the processed features

# Extract the fitted OneHotEncoder and StandardScaler components
ohe = preprocessor.named_transformers_['cat']
scaler = preprocessor.named_transformers_['num']

# Get feature names from the OneHotEncoder (for categorical features)
categorical_features_names = ohe.get_feature_names_out()

# Combine all feature names
all_feature_names = np.concatenate([categorical_features_names, numeric_features])

# 2. Extract Feature Importance Scores

# Get the fitted XGBoost model from the pipeline
xgb_model = pipeline_xgb.named_steps['model']

# Create a DataFrame of feature importances
importance_df = pd.DataFrame({
    'feature': all_feature_names,
    'importance': xgb_model.feature_importances_
})

# Sort by importance and display the top N features
top_n = 20
importance_df = importance_df.sort_values(by='importance', ascending=False).head(top_n)

# 3. Visualize Feature Importance
plt.figure(figsize=(10, 8))
plt.barh(importance_df['feature'], importance_df['importance'], color='coral')
plt.xlabel("Feature Importance (Gain)")
plt.title(f"Top {top_n} Feature Importances for XGBoost Model")
plt.gca().invert_yaxis() # Highest importance at the top
plt.tight_layout()
plt.savefig('xgb_feature_importance.png')

# %% [markdown]
# The most important feature for the model was unknown defensive coverage type, this may include all the different defenses or maybe just ones relating to a specific type of play. Such as defensive coverages specifically for rushing plays. Other features that showed importance in this model were formations both offense and defense as well as no huddle. There are also a few of possession teams which may indicate a specific play style by those teams, such as heavily running the ball throughout the game or passing the ball every first down.

# %% [markdown]
# # Results

# %% [markdown]
# Overall, this project gave insights into team strategies as well as if machine learning can predict play calls. While looking at the data, it is clear teams have different amount of call types but overall similar structure with passing being the most common play type followed by rushing plays. It is also clear that teams have different averages for the amount of yards gained based on play types which can be due various factors. Some of the factors include players on the field, and how the offensive play calls and defensive formation calls matter.
#
# When looking at the modeling section, all models performed very well. Evaluating the results generated, the XGBoost model was the best performing model not only through metrics but also through the confusion matrix showing similar results for classifying rushing plays but had the best results for classifying passing plays. In the evaluation process, I performed 2 types of testing, first being self generated data to test whether the model can predict between pass and rush, which did not prove the value of the model which then led me to my second option. I used the same API as before to collect data from 2025, using this current data, I ran the data through the model and visualized and evaluated the performance. As seen with the modeling section the performance was up to same standards as shown with my expirement. This means my model is also able to generalize really well, which can be due to using pre play information and nothing specific like players. It also is more current data which helps with current team patterns.
#
# The results of the models also shows something more meaningful. If play calls can be easily predicted, games would be very challening as teams wouldn't be able to progress down field, as the defense would know what the offense will do. Teams have to use trick plays or run different types of plays in different scenarios to try and throw the defense off of their game and progress down the field to score. This can even be noticed in games, for example, when watching the New York Giant's, rookie quarterback Jaxson Dart can be seen throwing short passes throughout the game, but when the game gets closer to the end and he is looking to score he will throw a deep pass even if the scenario would suggest doing something different. It can even be noticed in games where a running play is called and the quarterback decides to keep it and pass it off to a receiver or the complete opposite they are looking to throw and a gap opens up and they run with the ball.
#
# For future adaptations, this project can be utilized in a few ways. Starting off, it can be experimented with players on field, and see how players impact play call decisions. Second, this can turn into an application that can be used for teams to help decide play calls during games or during practices to prepare for upcoming games.
